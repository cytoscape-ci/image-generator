# %%
import requests

BASE = 'http://192.168.99.100:5000/'

# %%
res = requests.get(BASE)

print(res.json())
# Out:
# {'version': 'v1', 'serviceName': 'Graph image generator'}

# %%
msg = {
    "test": "foo"
}

image_url = BASE + 'image'

with open('example1.cx', 'r') as f:
    res = requests.post(image_url, data=f)

print(res.json())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-0401f488292f> in <module>()
#       5 image_url = BASE + 'image'
#       6
# ----> 7 with open('./example1.cx', 'r') as f:
#       8     res = requests.post(image_url, data=f)
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: './example1.cx'

# %%
from IPython.display import Image
from IPython.core.display import HTML

res = requests.get(BASE+'image')
Image(data=res.content, width=600)
